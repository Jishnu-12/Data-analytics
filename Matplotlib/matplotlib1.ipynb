# %% [markdown]
# # Matplot Lib

# %% [markdown]
# - Python Library
# - Low Level Graph plotting
# - Vishualization
# - Open Source , can use it freely
# - created by jhon D Hunter

# %%
import matplotlib

# %%
print(matplotlib.__version__)
# Out:
# 3.10.0

# %%
import matplotlib.pyplot as plt 
import numpy as np

# %%
x = np.array([0,6,8,10,12])
y  = np.array([0,25,23,54,22])

font1 ={"family":"monospace","color":"black","size":15}
style1 = {"color":"black","marker":"o","ms":12,"mec":"black","mfc":"black"}
style2 ={"color":"red","marker":"o","ms":10,"mec":"black","mfc":"red"}
# ms = markersize
# mec = markeredge colour
# mfc = marker phase colour
plt.plot(x,y,marker = "o",color = "black",ms=15,mec = "black",mfc = "w")
plt.xlabel("Id",fontdict = font1,loc= "right")
plt.ylabel("Age",fontdict = font1,loc = "bottom")
plt.title("Id/Age - Chart",fontdict = font1,loc = "left")
plt.style.use("default")
plt.show()

# %%
plt.plot(x,y,"o-.", ms = 7, mec = "black", mfc = "black" ,color ="black")
plt.show()

# %%
plt.plot(x,y,linestyle = "dashed",**style1) # unpacking dictionary
plt.show()

# %%
x1 = np.array([3,6,1,10])
y1 = np.array([6,2,7,11])

plt.plot(x1,**style1)
plt.plot(y1,**style2)
plt.xlabel("Id",fontdict = font1, loc = "right")
plt.ylabel("Age",fontdict = font1 , loc = "bottom")
plt.title("Id V/S Age",fontdict = font1 , loc = "left" , fontweight = "bold")
plt.grid(color = "green",linestyle = "--")
plt.xticks([0,1,2,3],["a","b","c","d"])
plt.show()

# %%
#plot1
x1 = np.array([1,2,3,4,5])
y1 = np.array([10,20,35,25,40])
plt.subplot(3,3,1)
plt.grid(color ="black")
plt.title("A")
plt.plot(x,y,color = "black",linestyle = "dotted")
#plot2
x1 = np.array([1,2,3,4,5])
y1 = np.array([15,25,30,20,45])
plt.subplot(3,3,2)
plt.title("B")
plt.grid(color = "black")
plt.plot(x,y,color = "black",linestyle = "dotted")
#plot3
x1 = np.array([1,2,3,4,5])
y1 = np.array([12,21,34,28,41])
plt.subplot(3,3,3)
plt.title("C")
plt.grid(color = "black")
plt.plot(x,y,color = "black",linestyle = "dotted")
#plot4
x1 = np.array([1,2,3,4,5])
y1 = np.array([12,18,26,23,32])
plt.subplot(3,3,4)
plt.title("D")
plt.grid(color = "black",linestyle = "dotted")
plt.plot(x,y,color = "black",linestyle = "dotted")
#plot5
x1 = np.array([1,2,3,4,5])
y1 = np.array([11,23,36,22,40])
plt.subplot(3,3,5)
plt.title("E")
plt.grid(color = "black")
plt.plot(x,y,color = "black",linestyle = "dotted")
#plot6
x1 = np.array([1,2,3,4,5])
y1 = np.array([9,15,25,29,38])
plt.subplot(3,3,6)
plt.title("F")
plt.grid(color = "black")
plt.plot(x,y,color = "black",linestyle = "dotted")
#plot7
x1 = np.array([1,2,3,4,5])
y1 = np.array([12,21,34,19,39])
plt.subplot(3,3,7)
plt.title("G")
plt.grid(color = "black")
plt.plot(x,y,color = "black",linestyle = "dotted")
#plot8
x1 = np.array([1,2,3,4,5])
y1 = np.array([15,25,44,34,46])
plt.subplot(3,3,8)
plt.title("H")
plt.grid(color = "black")
plt.plot(x,y,color = "black",linestyle = "dotted")
#plot9
x1 = np.array([1,2,3,4,5])
y1 = np.array([11,23,33,22,47])
plt.subplot(3,3,9)
plt.title("I")
plt.grid(color = "black")
plt.plot(x,y,color = "black",linestyle = "dotted")
plt.suptitle("multiple ploting / subploting",fontweight = "bold")
plt.show()

# %%
x = np.array([1,2,3,4,5,6,7])
y = np.array([21,12,34,25,35,23,10])

colors = ["red","black","purple","green","blue","orange","grey"]
sizes = [20,50,35,45,25,39,100]
# s = size
plt.scatter(x,y , color = colors, s = sizes)
plt.title("Scatter chart",fontweight = "bold" , loc = "left")
plt.grid()
plt.minorticks_on()
plt.show()

# %%
x = ['a','b','c','d']

y = [2,4,6,8]
colors = ['black','red','black','red']
plt.bar(x,y,color = colors,width = 0.1)
plt.title("Bar Chart",fontweight = "bold",loc = "left")
plt.show()

# %%
x = ['a','b','c','d','e']

y = [10,12,14,16,18]
colors = ['red','black','red','black','red']
plt.barh(x,y,color = colors,height = 0.5) # used to create horizontal bar graphs
plt.title("Horizontal Bar Chart",fontweight = "bold",loc = "left")
plt.show()

# %%
x = ['a','b','c','d']
y = [2,4,6,8]

colors = ['white','red','white','red']
plt.subplot(1,2,1)
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.title("A")
plt.bar(x,y,color = colors,width = 0.5)


x1= ['a','b','c','d','e']
y1 = [10,12,14,16,18]

colors = ['red','white','red','white','red']
plt.subplot(1,2,2)
plt.barh(x1,y1,color = colors , height = 0.5)
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.title("B")
plt.suptitle("Bar chart subploting")

plt.show()

# %%
x = np.random.normal(170,10,250)
plt.hist(x)
plt.style.use("dark_background")
plt.show()

# %%
x = [10,12,34,25]

label = ['a','b','c','d']
mc = ["red","purple","pink","orange"]
plt.pie(x,labels = label,explode = [0,0,0.1,0],startangle = 90,shadow = True,colors = mc, autopct = "%1.0f%%")
plt.legend(title = "alphabets",fontsize = 6,loc = "upper left")
plt.style.use("default")
plt.show()

# %%
x  = [0,1,2,3,4]
c1 = [21,23,25,23,12]
c2 = [12,34,54,23,45]
c3 = [32,23,54,21,44]

test = c1,c2,c3

plt.stackplot(x,c1,c2,c3)
plt.style.use("default")
plt.show()
