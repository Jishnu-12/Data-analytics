# %%
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd


data = {
    "Fruits": ["Apple", "Banana", "Orange", "Mango", "Grapes"],
    "Sold": [50, 75, 30, 100, 65],
    "Price": [120, 40, 60, 150, 90]
}

df = pd.DataFrame(data)
colors = ["red","yellow","orange","green","purple"]
plt.bar(df["Fruits"],df["Sold"],width = 0.6,color = colors,label = ["Apple", "Banana", "Orange", "Mango", "Grapes"])
plt.legend(title = "Price",fontsize = 7,loc = "upper left",labels = df["Price"])
plt.title("Fruits Sales",size = 16,family = "monospace",pad = 25,loc ="left")
plt.xlabel("Fruits",fontweight = "bold",labelpad = 15)
plt.ylabel("Sales" , fontweight = "bold")
plt.grid( linestyle = "--",color = "black")
plt.grid(which = "minor" , linestyle = ":" , color = "green")
plt.tick_params(axis = "x", rotation = 90 , labelsize = 8)
plt.minorticks_on()
plt.show()

# %%
colors = ["red","yellow","orange","green","purple"]

plt.pie(df["Sold"],labels = df["Fruits"],autopct = "%1.0f%%",shadow = True,explode = [0,0,0,0.2,0],colors = colors)
plt.axis("equal")
plt.title("fruits Sales pie chart",fontweight = "bold",size = 15,pad = 20)
plt.legend(fontsize = 6,labels = df["Price"],title = "price")

plt.show()

# %%
#plot1
colors = ["red","yellow","orange","green","purple"]
plt.subplot(3,3,1)
plt.bar(df["Fruits"],df["Sold"],width = 0.6,color = colors,label = ["Apple", "Banana", "Orange", "Mango", "Grapes"])
plt.title("A",size = 16,family = "monospace",fontweight = "bold",pad = 10)
plt.xlabel("Fruits",fontweight = "bold")
plt.ylabel("Sales" , fontweight = "bold")
plt.grid( linestyle = "--",color = "black")
plt.tick_params(axis='x', which='major', labelsize=5)
plt.grid(which = "minor" , linestyle = ":" , color = "green")
plt.minorticks_on()
#plot2
colors = ["red","yellow","orange","green","purple"]
plt.subplot(3,3,2)
plt.pie(df["Sold"],labels = df["Fruits"],autopct = "%1.0f%%",shadow = True,explode = [0,0,0,0.2,0],colors = colors,textprops = {"fontsize":5})
plt.axis("equal")
plt.title("B",fontweight = "bold",size = 15,pad = 10)
plt.figlegend(fontsize = 6,labels = df["Price"],title = "price")
plt.suptitle("Sub Plotting Diffrent Chart's",family = "monospace",size = 16,y = 1.1)

#plot3
x1 = np.array([3,6,1,10,3])
y1 = np.array([6,2,7,13,5])

plt.subplot(3,3,3)
plt.plot(x1,color = "black",mec = "black",mfc = "red",marker = "o")
plt.plot(y1,color = "red",mec = "red",mfc = "black",marker = "o")
plt.xlabel("Id",size = 8)
plt.ylabel("Age", size = 8)
plt.title("c",fontweight="bold")
plt.grid(color = "green",linestyle = "--")
plt.xticks([0,1,3,4],["a","b","c","d"])

#plot4
x = np.array([1,2,3,4,5,6,7])
y = np.array([21,12,34,25,35,23,10])

colors = ["red","black","purple","green","blue","orange","grey"]
sizes = [20,50,35,45,25,39,100]
# s = size
plt.subplot(3,3,4)
plt.scatter(x,y , color = colors, s = sizes)
plt.title("D",fontweight = "bold")
plt.grid()
plt.minorticks_on()
#plot5
x = ['a','b','c','d']
y = [2,4,6,8]
colors = ['black','red','black','red']
plt.subplot(3,3,5)
plt.bar(x,y,color = colors)
plt.title("D",fontweight = "bold")
#plot6
x = ['a','b','c','d','e']
y = [10,12,14,16,18]
plt.subplot(3,3,6)
colors = ['red','black','red','black','red']
plt.barh(x,y,color = colors) # used to create horizontal bar graphs
plt.title("E",fontweight = "bold")
plt.tight_layout()
plt.savefig("multiple.jpg",dpi = 250,bbox_inches = "tight")
plt.show()
